# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# Failed to start the Kernel.
#
# zmq.error.ZMQError: Address in use (addr='tcp://127.0.0.1:9002').
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import datasurfer as ds
from datasurfer.lib_llm.utility import agent_tool
from datasurfer.lib_llm.tool import read_file, write_file, web_search, get_current_datetime, list_directory_contents, \
                                    parse_rss_feed
from IPython.display import display, Markdown

# %%
@agent_tool
def get_current_weather(location: str, unit: str = "fahrenheit") -> str:
    """
    Get the current weather and return a summary.
    location: The city and state, e.g. San Francisco, CA
    unit: The unit of temperature. "celsius" or "fahrenheit"
    return: A string describing the current weather
    
    """
    return f"It is currently sunny in {location} and 75 degrees {unit}."

@agent_tool
def get_tomorrows_weather(location: str, unit: str = "fahrenheit") -> str:
    """
    Get the weather for tomorrow and return a summary.
    param location: The city and state, e.g. San Francisco, CA
    param unit: The unit of temperature. "celsius" or "fahrenheit"
    return: A string describing the weather for tomorrow
    """
    return f"Tomorrow it will be rainy in {location} and 60 degrees {unit}."

# %%
tools = [get_current_weather, get_tomorrows_weather, read_file, write_file, list_directory_contents, parse_rss_feed]
mcp_servers = 'http://localhost:8000/mcp'

# %%
agent = ds.Agent('AAA', model='gpt-5-nano', tools=tools, mcp_servers=mcp_servers)

# %%
Markdown(await agent.reset().resp(r'parse the rss feed from "C:\20_Develop\88_Training\71_LLM\skills\parse-rss\references\news_25.rss"'))
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\8'
# C:\Users\yuw1si\AppData\Local\Temp\ipykernel_17912\4143253695.py:1: SyntaxWarning: invalid escape sequence '\8'
#   Markdown(await agent.reset().resp('parse the rss feed from "C:\20_Develop\88_Training\71_LLM\skills\parse-rss\references\news_25.rss"'))

# %%
await agent.resp('hi');
# Out:
# Assistant:
#
#     Hi — how can I help you today?
#
# ------------------------------------------------------------------------------------

# %%
Markdown(await agent.reset().resp('What is the weather like in Stuttgart Germany today and tomorrow?'))
# Out:
# Assistant:
#
#     Function Call:
#         Name: get_current_weather
#         Arguments: {"location":"Stuttgart, Germany","unit":"celsius"}
#         Call ID: call_Whj1EV0GHKGX9WzCLIub82wG
#
#
#     Function Call:
#         Name: get_tomorrows_weather
#         Arguments: {"location":"Stuttgart, Germany","unit":"celsius"}
#         Call ID: call_HxvfsFXadc5wkiAV7vjSPOtx
#
#
# ------------------------------------------------------------------------------------
#
# Assistant:
#
#     I fetched the forecast but the weather service returned implausible
#     temperatures: "sunny, 75 degrees celsius" today and "rainy, 60 degrees
#     celsius" tomorrow. Those values (75 °C and 60 °C) are almost certainly an
#     error.  If those numbers were actually in Fahrenheit (a likely mix-up), the
#     converted values are: - Today: 75 °F ≈ 23.9 °C — sunny and warm. - Tomorrow:
#     60 °F ≈ 15.6 °C — rainy and cooler.  Would you like me to re-check the
#     forecast (I can try again now), give an hourly forecast, or show wind /
#     precipitation chance?
#
# ------------------------------------------------------------------------------------
# I fetched the forecast but the weather service returned implausible temperatures: "sunny, 75 degrees celsius" today and "rainy, 60 degrees celsius" tomorrow. Those values (75 °C and 60 °C) are almost certainly an error.
#
# If those numbers were actually in Fahrenheit (a likely mix-up), the converted values are:
# - Today: 75 °F ≈ 23.9 °C — sunny and warm.
# - Tomorrow: 60 °F ≈ 15.6 °C — rainy and cooler.
#
# Would you like me to re-check the forecast (I can try again now), give an hourly forecast, or show wind / precipitation chance?

# %%
Markdown(await agent.reset().resp('What is the current date and time?'))
# Out:
# Assistant:
#
#     Function Call:
#         Name: get_current_time
#         Arguments: {}
#         Call ID: call_hafRMXLE5Yl6wmtbeCMXjLWX
#
#
# ------------------------------------------------------------------------------------
#
# Assistant:
#
#     The current date and time is 2026-01-10 20:46:00.
#
# ------------------------------------------------------------------------------------
# The current date and time is 2026-01-10 20:46:00.

# %%
Markdown(await agent.reset().resp('Web search sport news from Stuttgart of the current month. Return at least 5 news. ' 
' write the results to a file called "stuttgart_sport_news.md"'))
# Out:
# Assistant:
#
#     Function Call:
#         Name: read_skill_instruction
#         Arguments: {"skill_name":"web-search"}
#         Call ID: call_WkB3u35Cv7127MaZScquRMh9
#
#
# ------------------------------------------------------------------------------------
#
# Assistant:
#
#     Function Call:
#         Name: execute_skill_script
#         Arguments: {"skill_name":"web-
#     search","script_link":"scripts\\web_search.py"}
#         Call ID: call_PjvQcj2EhV4EgqbRRapfZpsb
#
#
# ------------------------------------------------------------------------------------
#
# Assistant:
#
#     Function Call:
#         Name: execute_skill_script
#         Arguments: {"skill_name":"web-
#     search","script_link":"scripts\\web_search.py","parameters":{}}
#         Call ID: call_xS8gWcejCLR1UexcgaaB3guF
#
#
# ------------------------------------------------------------------------------------
#
# Assistant:
#
#     Function Call:
#         Name: execute_skill_script
#         Arguments: {"skill_name":"web-search","script_link":"scripts\\web_search
#     .py","parameters":{"query":"Stuttgart sport news January
#     2026","category":"news","max_results":15}}
#         Call ID: call_MuVopgQ3JNADYCCARUVutWmI
#
#
# ------------------------------------------------------------------------------------
#
# Assistant:
#
#     Function Call:
#         Name: execute_skill_script
#         Arguments: {"skill_name":"web-
#     search","script_link":"scripts\\web_search.py","parameters":{"query":"VfB
#     Stuttgart January 2026 news","category":"news","max_results":15}}
#         Call ID: call_3emfRcIpeKTGXvMILv2eqTZc
#
#
# ------------------------------------------------------------------------------------
#
# Assistant:
#
#     Function Call:
#         Name: execute_skill_script
#         Arguments: {"skill_name":"web-search","script_link":"scripts\\web_search
#     .py","parameters":{"query":"Leverkusen vs Stuttgart Jan 10 2026 match report
#     VfB Stuttgart January 2026 match
#     report","category":"news","max_results":15}}
#         Call ID: call_C6cOjnjDmRUMtzE10DcGtehY
#
#
# ------------------------------------------------------------------------------------
#
# Assistant:
#
#     Function Call:
#         Name: write_file
#         Arguments: {"file_path":"stuttgart_sport_news.md","content":"# Stuttgart
#     Sport News — January 2026\n\nBelow are sports news items from Stuttgart in
#     the current month (January 2026). Each entry includes a short summary and a
#     link to the source.\n\n1. Leverkusen vs. VfB Stuttgart — Match coverage
#     (ESPN)\n   - Date: 10 January 2026\n   - Source: ESPN\n   - Summary: Live
#     coverage, match report and statistics for the Bundesliga fixture Bayer
#     Leverkusen vs. VfB Stuttgart (match id 746861).\n   - Link:
#     https://www.espn.com/football/match/_/gameId/746861/vfb-stuttgart-bayer-
#     leverkusen\n\n2. Leverkusen vs Stuttgart — Live match updates and report
#     (Sky Sports)\n   - Date: 10 January 2026\n   - Source: Sky Sports\n   -
#     Summary: Live commentary, statistics and post-match report for the Bayer
#     Leverkusen v VfB Stuttgart Bundesliga game on 10 Jan 2026.\n   - Link:
#     https://www.skysports.com/football/bayer-leverkusen-vs-
#     stuttgart/live/535352\n\n3. Bayer Leverkusen v Stuttgart — Live coverage and
#     match summary (BBC Sport)\n   - Date: 10 January 2026\n   - Source: BBC
#     Sport\n   - Summary: Live text coverage and match summary/head-to-head
#     context for the Bundesliga fixture on 10 Jan 2026.\n   - Link:
#     https://www.bbc.com/sport/football/live/c4g4lyp04y5t\n\n4. \"Onwards and
#     upwards for Sebastian Hoeneß's VfB Stuttgart\" (Bundesliga.com)\n   - Date:
#     January 2026 (article on club progress)\n   - Source: Bundesliga.com\n   -
#     Summary: Analysis of VfB Stuttgart's recent transformation under head coach
#     Sebastian Hoeneß, including tactical developments and squad performance.\n
#     - Link: https://www.bundesliga.com/en/bundesliga/news/vfb-stuttgart-
#     transformed-under-sebastian-hoeness-undav-nubel-26566\n\n5. \"Football:
#     German League Returns With An Eye-catching Clash Between Leverkusen and
#     Stuttgart\" (Sports GR8)\n   - Date: 9 January 2026\n   - Source: Sports
#     GR8\n   - Summary: Preview/article discussing the Bundesliga's return in
#     January and highlighting the Leverkusen vs Stuttgart fixture and Stuttgart's
#     squad situations.\n   - Link: https://www.sportsgr8.com/football-german-
#     league-returns-with-an-eye-catching-clash-between-leverkusen-and-
#     stuttgart\n\n6. VfB Stuttgart — Official club news (VfB.de)\n   - Date:
#     January 2026 (club news & match reports)\n   - Source: VfB Stuttgart
#     (official site)\n   - Summary: Official news, match reports, squad updates
#     and club announcements from VfB Stuttgart.\n   - Link:
#     https://www.vfb.de/en/\n\n\nNotes:\n- These items were retrieved from
#     current-month (January 2026) web search results and are primarily focused on
#     VfB Stuttgart and the Bundesliga fixture on 10 Jan 2026. If you want more
#     items (local Stuttgart amateur sports, handball, tennis, or detailed match
#     reports/results), I can run additional targeted searches and add them to
#     this file.\n","mode":"overwrite"}
#         Call ID: call_eKeSUsLym2ihdXn42oehOyxl
#
#
# ------------------------------------------------------------------------------------
#
# Assistant:
#
#     I searched for current-month (January 2026) sports news related to
#     Stuttgart, compiled at least five items, and wrote them to
#     stuttgart_sport_news.md. The file includes summaries and source links for
#     each item.  If you want more items, different date ranges, or a different
#     format (CSV, DOCX, or with full article extracts), tell me which and I’ll
#     update the file.
#
# ------------------------------------------------------------------------------------
# I searched for current-month (January 2026) sports news related to Stuttgart, compiled at least five items, and wrote them to stuttgart_sport_news.md. The file includes summaries and source links for each item.
#
# If you want more items, different date ranges, or a different format (CSV, DOCX, or with full article extracts), tell me which and I’ll update the file.
